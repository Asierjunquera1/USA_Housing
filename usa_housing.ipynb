# %% [markdown]
# IMPORTACION DE LIBRERIAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# CREACION DEL DATAFRAME

# %%
df=pd.read_csv("USA_Housing.csv")
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# FILTRADO DE DATOS

# %%
print(df.isnull().sum())
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# No hay datos nulos ni repetidos

# %% [markdown]
# GRAFICAS

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["Avg. Area House Age"], df["Price"])
plt.xlabel("Edad promedio de las casas en el area")
plt.ylabel("Precio")
plt.title("Edad promedio de las casa en el area vs Precio")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df["Avg. Area Income"], bins=20)
plt.xlabel("Ingreso promedio del area")
plt.ylabel("Frecuancia")
plt.title("Distribucion del ingreso promedio del area")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df["Avg. Area Number of Rooms"])
plt.xlabel("Numero promedio de habitantes en el area")
plt.title("Diagrama de caja del promedio de habitantes en el area")
plt.show()

# %%
rangos_poblacion = pd.cut(df["Area Population"], bins=5)
precio_promedio_por_poblacion = df.groupby(rangos_poblacion)['Price'].mean()

plt.figure(figsize=(8, 6))
precio_promedio_por_poblacion.plot(kind="bar")
plt.xlabel("Rango de población")
plt.ylabel("Precio promedio")
plt.title("Precio promedio por rango de población")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.regplot(x="Avg. Area Income", y="Price", data=df)
plt.xlabel("Ingreso Promedio del Área")
plt.ylabel("Precio")
plt.title("Ingreso Promedio del Área vs. Precio")
plt.show()

# %% [markdown]
# CORRELACION
